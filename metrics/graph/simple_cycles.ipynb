# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
# edges = [(0, 0), (0, 1), (0, 2), (1, 2), (2, 0), (2, 1), (2, 2)]
edges = [(0,0), (0,1), (1,0), (0, 3), (3, 0), (1, 3), (3, 1)]
G = nx.DiGraph(edges)
list(nx.simple_cycles(G))
type(edges)
# Out:
# list

# %%
plt.subplot()
nx.draw(G, with_labels=True)

# %%
import scipy.io as sio

# %%
mat = sio.loadmat('/Users/harangju/Developer/ws_c_2_p0_0.mat', squeeze_me = True)
edges = mat['e']
weights = mat['w']
G = nx.DiGraph(edges.tolist())
plt.subplot()
nx.draw(G, with_labels=True)
cycle_gen = nx.simple_cycles(G)
cycles = list(cycle_gen)
len(cycles)
# cycles
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2909                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2910                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2911             finally:
#
# <ipython-input-5-225574592f16> in <module>()
#       7 cycle_gen = nx.simple_cycles(G)
# ----> 8 cycles = list(cycle_gen)
#       9 len(cycles)
#
# /anaconda3/lib/python3.6/site-packages/networkx/algorithms/cycles.py in simple_cycles(G)
#     220 #                assert path[-1] == thisnode
# --> 221                 path.pop()
#     222         # done processing this node
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
mat = sio.loadmat('/Users/harangju/Developer/ws_c_2_p1_0.mat', squeeze_me = True)
edges = mat['e']
weights = mat['w']
G = nx.DiGraph(edges.tolist())
plt.subplot()
nx.draw(G, with_labels=True)t
cycle_gen = nx.simple_cycles(G)
cycles = list(cycle_gen)
len(cycles)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-81ad612f3b92> in <module>()
#       6 nx.draw(G, with_labels=True)
#       7 cycle_gen = nx.simple_cycles(G)
# ----> 8 cycles = list(cycle_gen)
#       9 len(cycles)
#
# /anaconda3/lib/python3.6/site-packages/networkx/algorithms/cycles.py in simple_cycles(G)
#     205                 elif nextnode not in blocked:
#     206                     path.append(nextnode)
# --> 207                     stack.append((nextnode, list(subG[nextnode])))
#     208                     closed.discard(nextnode)
#     209                     blocked.add(nextnode)
#
# /anaconda3/lib/python3.6/site-packages/networkx/classes/coreviews.py in __iter__(self)
#      50
#      51     def __iter__(self):
# ---> 52         return iter(self._atlas)
#      53
#      54     def __getitem__(self, key):
#
# KeyboardInterrupt:

# %%
# find weights of cycles
cycle_weights = np.ones((len(cycles),1))
for i in range(0,len(cycles)):
    for j in range(0,len(cycles[i])-1):
        node1 = cycles[i][j]
        node2 = cycles[i][j+1]
        idx_edge = edges.tolist().index([node1, node2])
        cycle_weights[i] = cycle_weights[i] * weights[idx_edge]

# %%
# find expected duration of cycle
cycle_dur_exp = np.ones((len(cycles),1))
for i in range(0,len(cycles)):
    cycle_dur_exp[i] = len(cycles[i]) * cycle_weights[i]
# cycle_dur_exp
